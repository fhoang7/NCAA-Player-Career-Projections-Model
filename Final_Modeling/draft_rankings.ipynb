# %% [markdown]
# # Goal:
# Rack and stack all of the 2020 NBA draft class prospects for our shiny app.

# %% [markdown]
# Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import getpass
import psycopg2
from sklearn.preprocessing import scale, LabelEncoder, LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, f1_score
from sklearn.model_selection import train_test_split
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
sns.set_style('whitegrid')
sns.set(rc = {'figure.figsize':(12, 8)})

# %% [markdown]
# Connect to our database

# %%
mypasswd = getpass.getpass()
conn = psycopg2.connect(database = 'cs20_group4',
                              user = 'jpcp73', #replace with pawprint
                              host = 'pgsql.dsa.lan',
                              password = mypasswd)
cursor = conn.cursor()
# Out:
# ········

# %% [markdown]
# Query our 2020 NBA Draft class predictions from our database

# %%
data = pd.read_sql_query("""
SELECT
    *
FROM active_player_predictions
""", con = conn)
print(data.shape)
data.head()
# Out:
# (5111, 11)
#               ncaa_id       player_name  nba_pred predicted_career_role  \
# 0      iran-bennett-1      Iran Bennett  1.000000               Non-NBA
# 1      jakub-dombek-1      Jakub Dombek  0.998781    Replacement Player
# 2    shakur-juiston-1    Shakur Juiston  1.000000               Reserve
# 3  maxwell-starwood-1  Maxwell Starwood  1.000000               Non-NBA
# 4     james-wiseman-1     James Wiseman  1.000000                  Star
#
#    benchwarmer_prob  non_nba_prob  replacement_player_prob  \
# 0      8.125922e-08  5.543595e-01             3.918272e-01
# 1      0.000000e+00  0.000000e+00             1.000000e+00
# 2      2.000015e-11  3.197494e-01             3.438615e-22
# 3      1.346084e-13  9.999917e-01             5.807572e-14
# 4      1.126775e-07  1.482664e-15             1.548839e-10
#
#    reserve_player_prob  role_player_prob  star_player_prob  \
# 0         2.564247e-04      8.213609e-03      8.715020e-07
# 1         0.000000e+00      0.000000e+00      0.000000e+00
# 2         6.801035e-01      7.102528e-18      2.260053e-12
# 3         8.159463e-06      2.181801e-07      1.783722e-11
# 4         1.739439e-09      2.910505e-07      9.999994e-01
#
#    starter_player_prob
# 0         4.534241e-02
# 1         0.000000e+00
# 2         1.470853e-04
# 3         5.009856e-08
# 4         1.863512e-07

# %% [markdown]
# Create a composite score that sums up our model's probabilities for each player so we can compare all of the 2020 draft prospects.

# %%
data['player_score'] = (-1 * data.non_nba_prob) + (1 * data.replacement_player_prob) + (2 * data.benchwarmer_prob) + \
                       (3 * data.reserve_player_prob) + (4 * data.role_player_prob) + (5 * data.starter_player_prob) + \
                       (6 * data.star_player_prob)

# %% [markdown]
# View our results

# %%
data.sort_values(by = 'player_score', ascending = False).head(30)[['ncaa_id', 'player_name', 'predicted_career_role', 'player_score']]
# Out:
#                   ncaa_id        player_name predicted_career_role  \
# 6       anthony-edwards-2    Anthony Edwards                  Star
# 354        jordan-nwora-1       Jordan Nwora                  Star
# 4         james-wiseman-1      James Wiseman                  Star
# 55          nfaly-dante-1       N'Faly Dante                  Star
# 58            tre-jones-1          Tre Jones                  Star
# 60     precious-achiuwa-1   Precious Achiuwa                  Star
# 51           josh-green-2         Josh Green                  Star
# 1040       marcus-evans-2       Marcus Evans                  Star
# 10       isaiah-stewart-2     Isaiah Stewart                  Star
# 93       onyeka-okongwu-1     Onyeka Okongwu                  Star
# 116     cassius-winston-1    Cassius Winston               Starter
# 554        chris-smith-19        Chris Smith               Starter
# 573      chris-johnson-14      Chris Johnson               Starter
# 29      jaden-mcdaniels-1    Jaden McDaniels               Starter
# 558         greg-smith-16         Greg Smith               Starter
# 342        steven-enoch-1       Steven Enoch               Starter
# 31         nico-mannion-1       Nico Mannion               Starter
# 275       markus-howard-1      Markus Howard               Starter
# 141         isaac-okoro-1        Isaac Okoro               Starter
# 435        tyrell-terry-1       Tyrell Terry               Starter
# 357        temple-gibbs-1         T.J. Gibbs               Starter
# 206   rayshaun-hammonds-1  Rayshaun Hammonds               Starter
# 568        xavier-sneed-1       Xavier Sneed               Starter
# 192         roman-silva-1        Roman Silva               Starter
# 359     jordan-williams-3    Jordan Williams               Starter
# 191        anton-watson-1       Anton Watson               Starter
# 246      pavel-zakharov-1     Pavel Zakharov               Starter
# 497       isaiah-bailey-1      Isaiah Bailey               Starter
# 534         skylar-mays-1        Skylar Mays               Starter
# 345       chase-johnson-1      Chase Johnson               Starter
#
#       player_score
# 6         6.000000
# 354       6.000000
# 4         5.999999
# 55        5.999024
# 58        5.977293
# 60        5.953998
# 51        5.912573
# 1040      5.895392
# 10        5.287022
# 93        5.214092
# 116       5.000000
# 554       4.999998
# 573       4.999978
# 29        4.999967
# 558       4.999926
# 342       4.999912
# 31        4.999886
# 275       4.999442
# 141       4.999023
# 435       4.998900
# 357       4.998448
# 206       4.991791
# 568       4.989805
# 192       4.988652
# 359       4.979964
# 191       4.965736
# 246       4.964817
# 497       4.962059
# 534       4.956963
# 345       4.956027

# %% [markdown]
# Define our `draft_rankings` data table schema

# %%
cursor = conn.cursor()
c_table = []
for c in data.columns.tolist():
    if data[c].dtype in [float, int, 'int64']:
        c_table.append('{} numeric'.format(c))
    elif data[c].dtype == 'datetime64[ns]':
        c_table.append('{} TIMESTAMP'.format(c))
    else:
        c_table.append('{} varchar({})'.format(c, max([len(str(x)) for x in data[c] if x is not None])))
create_table = 'DROP TABLE IF EXISTS draft_rankings; '
create_table += 'CREATE TABLE draft_rankings ({})'.format(', '.join(c for c in c_table))
cursor.execute(create_table)
conn.commit()

# %% [markdown]
# Insert our rankings data into the `draft_rankings` data table

# %%
df = data.where(pd.notnull(data), None)
cursor = conn.cursor()
INSERT_SQL = 'INSERT INTO draft_rankings'
INSERT_SQL += '({}) VALUES'.format(', '.join([x for x in df.columns]))
INSERT_SQL += '({})'.format(''.join(['%s,' * len(df.columns)])[:-1])
with conn, conn.cursor() as cursor:
    for row in df.itertuples(index=False, name=None):
        cursor.execute(INSERT_SQL, row)
