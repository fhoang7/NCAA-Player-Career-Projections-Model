# %% [markdown]
# ## Goal:
# Create a table inside our database with the NCAA Advanced Boxscore data.
#
# Import packages

# %%
import pandas as pd
import numpy as np
import time
import getpass
from datetime import datetime
import psycopg2
from psycopg2.extensions import adapt, register_adapter, AsIs
pd.set_option('display.max_columns', 500)

# %% [markdown]
# Read in dataset

# %%
ncaa_advanced_boxscores = pd.read_csv('../Data/ncaa_advanced_boxscores.csv')

# %%
ncaa_advanced_boxscores.head()
# Out:
#                   boxscore  away_assist_percentage  away_assists  \
# 0     2018-11-06-19-kansas                   0.731            19
# 1   2018-11-06-21-kentucky                   0.512            22
# 2    2018-11-06-21-gonzaga                   0.500            16
# 3   2018-11-06-19-virginia                   0.000             0
# 4  2018-11-06-19-tennessee                   0.500             7
#
#    away_block_percentage  away_blocks  away_defensive_rating  \
# 0                  0.152            7                  105.7
# 1                  0.071            3                  101.2
# 2                  0.043            2                  148.1
# 3                  0.000            0                  128.1
# 4                  0.022            1                  116.2
#
#    away_defensive_rebound_percentage  away_defensive_rebounds  \
# 0                              0.744                       32
# 1                              0.735                       25
# ...

# %% [markdown]
# Connect to PostGres database

# %%
mypasswd = getpass.getpass()
conn = psycopg2.connect(database = 'cs20_group4',
                              user = 'jpcp73',
                              host = 'pgsql.dsa.lan',
                              password = mypasswd)
# Out:
# ········

# %% [markdown]
# Create table in database

# %%
cursor = conn.cursor()

# %%
create_table = """
DROP TABLE IF EXISTS ncaa_advanced_boxscores;
CREATE TABLE ncaa_advanced_boxscores (
boxscore varchar(50) primary key,
away_assist_percentage numeric,
away_assists integer,
away_block_percentage numeric,
away_blocks integer,
away_defensive_rating numeric,
away_defensive_rebound_percentage numeric,
away_defensive_rebounds integer,
away_effective_field_goal_percentage numeric,
away_field_goal_attempts integer,
away_field_goal_percentage numeric,
away_field_goals integer,
away_free_throw_attempt_rate numeric,
away_free_throw_attempts integer,
away_free_throw_percentage numeric,
away_free_throws_made integer,
away_losses integer,
away_minutes_played integer,
away_offensive_rating numeric,
away_offensive_rebound_percentage numeric,
away_offensive_rebounds integer,
away_personal_fouls integer,
away_points integer,
away_ranking integer,
away_steal_percentage numeric,
away_steals integer,
away_three_point_attempt_rate numeric,
away_three_point_field_goal_attempts integer,
away_three_point_field_goal_percentage numeric,
away_three_point_field_goals integer,
away_total_rebound_percentage numeric,
away_total_rebounds integer,
away_true_shooting_percentage numeric,
away_turnover_percentage numeric,
away_turnovers integer,
away_two_point_field_goal_attempts integer,
away_two_point_field_goal_percentage numeric,
away_two_point_field_goals integer,
away_win_percentage numeric,
away_wins integer,
date date,
home_assist_percentage numeric,
home_assists integer,
home_block_percentage numeric,
home_blocks integer,
home_defensive_rating numeric,
home_defensive_rebound_percentage numeric,
home_defensive_rebounds integer,
home_effective_field_goal_percentage numeric,
home_field_goal_attempts integer,
home_field_goal_percentage numeric,
home_field_goals integer,
home_free_throw_attempt_rate numeric,
home_free_throw_attempts integer,
home_free_throw_percentage numeric,
home_free_throws_made integer,
home_losses integer,
home_minutes_played integer,
home_offensive_rating numeric,
home_offensive_rebound_percentage numeric,
home_offensive_rebounds integer,
home_personal_fouls integer,
home_points integer,
home_ranking integer,
home_steal_percentage numeric,
home_steals integer,
home_three_point_attempt_rate numeric,
home_three_point_field_goal_attempts integer,
home_three_point_field_goal_percentage numeric,
home_three_point_field_goals integer,
home_total_rebound_percentage numeric,
home_total_rebounds integer,
home_true_shooting_percentage numeric,
home_turnover_percentage numeric,
home_turnovers integer,
home_two_point_field_goal_attempts integer,
home_two_point_field_goal_percentage numeric,
home_two_point_field_goals integer,
home_win_percentage numeric,
home_wins integer,
location varchar(100),
losing_abbr varchar(50),
losing_name varchar(50),
pace numeric,
winner varchar(10),
winning_abbr varchar(50),
winning_name varchar(50)
)
"""

# %% [markdown]
# Execute create table statement

# %%
cursor.execute(create_table)

# %%
conn.commit()

# %% [markdown]
# Insert data into newly created table

# %%
ncaa_advanced_boxscores = ncaa_advanced_boxscores.where(pd.notnull(ncaa_advanced_boxscores), None)

INSERT_SQL = 'INSERT INTO ncaa_advanced_boxscores'
INSERT_SQL += '(boxscore,away_assist_percentage,away_assists,'
INSERT_SQL +='away_block_percentage,away_blocks,away_defensive_rating,'
INSERT_SQL +='away_defensive_rebound_percentage,away_defensive_rebounds,'
INSERT_SQL +='away_effective_field_goal_percentage,away_field_goal_attempts,'
INSERT_SQL +='away_field_goal_percentage,away_field_goals,'
INSERT_SQL +='away_free_throw_attempt_rate,away_free_throw_attempts,'
INSERT_SQL +='away_free_throw_percentage,away_free_throws_made,away_losses,'
INSERT_SQL +='away_minutes_played,away_offensive_rating,'
INSERT_SQL +='away_offensive_rebound_percentage,away_offensive_rebounds,'
INSERT_SQL +='away_personal_fouls,away_points,away_ranking,'
INSERT_SQL +='away_steal_percentage,away_steals,away_three_point_attempt_rate,'
INSERT_SQL +='away_three_point_field_goal_attempts,'
INSERT_SQL +='away_three_point_field_goal_percentage,'
INSERT_SQL +='away_three_point_field_goals,away_total_rebound_percentage,'
INSERT_SQL +='away_total_rebounds,away_true_shooting_percentage,'
INSERT_SQL +='away_turnover_percentage,away_turnovers,'
INSERT_SQL +='away_two_point_field_goal_attempts,'
INSERT_SQL +='away_two_point_field_goal_percentage,away_two_point_field_goals,'
INSERT_SQL +='away_win_percentage,away_wins,date,home_assist_percentage,'
INSERT_SQL +='home_assists,home_block_percentage,home_blocks,'
INSERT_SQL +='home_defensive_rating,home_defensive_rebound_percentage,'
INSERT_SQL +='home_defensive_rebounds,home_effective_field_goal_percentage,'
INSERT_SQL +='home_field_goal_attempts,home_field_goal_percentage,'
INSERT_SQL +='home_field_goals,home_free_throw_attempt_rate,'
INSERT_SQL +='home_free_throw_attempts,home_free_throw_percentage,'
INSERT_SQL +='home_free_throws_made,home_losses,home_minutes_played,'
INSERT_SQL +='home_offensive_rating,home_offensive_rebound_percentage,'
INSERT_SQL +='home_offensive_rebounds,home_personal_fouls,home_points,'
INSERT_SQL +='home_ranking,home_steal_percentage,home_steals,'
INSERT_SQL +='home_three_point_attempt_rate,home_three_point_field_goal_attempts,'
INSERT_SQL +='home_three_point_field_goal_percentage,'
INSERT_SQL +='home_three_point_field_goals,home_total_rebound_percentage,'
INSERT_SQL +='home_total_rebounds,home_true_shooting_percentage,'
INSERT_SQL +='home_turnover_percentage,home_turnovers,'
INSERT_SQL +='home_two_point_field_goal_attempts,'
INSERT_SQL +='home_two_point_field_goal_percentage,home_two_point_field_goals,'
INSERT_SQL +='home_win_percentage,home_wins,location,losing_abbr,'
INSERT_SQL +='losing_name,pace,winner,winning_abbr,winning_name) VALUES '
INSERT_SQL += '(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,'
INSERT_SQL += '%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,'
INSERT_SQL += '%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,'
INSERT_SQL += '%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,'
INSERT_SQL += '%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,'
INSERT_SQL += '%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,'
INSERT_SQL += '%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,'
INSERT_SQL += '%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,'
INSERT_SQL += '%s,%s,%s,%s,%s,%s,%s)'

with conn, conn.cursor() as cursor:
    for row in ncaa_advanced_boxscores.itertuples(index=False, name=None):
        cursor.execute(INSERT_SQL,row)
